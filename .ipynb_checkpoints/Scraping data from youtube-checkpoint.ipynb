# %%
import pandas as pd
import requests
import json

# %%
api_key = 'Hiden' # hide my api key

# %%
#channelid
channel_Id = 'UCdnBdcPkmvEU_JK3_SFDxtw' #Quang Linh Vlog

# %%
# For channel's basic statics
url1 = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&key={api_key}&id={channel_Id}"
channel_info = requests.get(url1)
json_data1 = json.loads(channel_info.text)
json_data1
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'O3LuXoIi8Ggm4goJZ0WX_Gh3SQQ',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'uDavTnrjFpQcUHmPULF7OpMaJL0',
#    'id': 'UCdnBdcPkmvEU_JK3_SFDxtw',
#    'statistics': {'viewCount': '32622333',
#     'subscriberCount': '239000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '135'}}]}

# %%
channel_subscribers = int(json_data1['items'][0]['statistics']['subscriberCount']);
channel_videos = int(json_data1['items'][0]['statistics']['videoCount']);
channel_views = int(json_data1['items'][0]['statistics']['viewCount']);

print('Total Subsribers =',channel_subscribers, '\nTotal Videos =', channel_videos, '\nTotal Views =', channel_views)
# Out:
# Total Subsribers = 239000
# Total Videos = 135
# Total Views = 32622333

# %%
limit = 10 # how many pages of information you want
video_Ids = []
nextPageToken =""
for i in range(limit):
    url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&part=snippet&channelId={channel_Id}&maxResults=20&pageToken={nextPageToken}"
    data = json.loads(requests.get(url).text)

# %%
for item in data['items']: 
  if item['id']['kind'] == 'youtube#video':
        video_Id = str(item['id']['videoId'])
        video_Ids.append(video_Id)  # Storing video Ids for extracting videos information
nextPageToken = data['nextPageToken'] # to collect videos from the next page

# %%
video_Ids
# Out:
# ['JMwfg3RzXZQ',
#  'jqzO-srikcs',
#  'Anq36w5xCRo',
#  'CNrT7dCWoZk',
#  'kBVonIkqqBQ',
#  'CH1vLRyacik',
#  'oXfyFJ0HhT4',
#  'oZhf7QxptYc',
#  'YEKnHgW5D8c',
#  '7gnu4jFAzFE',
#  'MUM6KqU1zVs',
#  'N5E2s0oZU2M',
#  'wK9CarB3Mvc',
#  '5T5PTcDa5qY',
#  'V7N3qxiFSu8',
#  'w2iawqLnk24',
#  'l6XBhme6z5c',
#  '_HIpiVLlWUI',
#  'OgLQOlzEr1o']

# %%
data_df = pd.DataFrame(columns=['video_id', 'channel_id', 'published_date', 'video_title', 'video_description', 'likes', 'views', 'comment_count'])

# %%
data_df.head()
# Out:
# Empty DataFrame
# Columns: [video_id, channel_id, published_date, video_title, video_description, likes, views, comment_count]
# Index: []

# %%
data
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'DBmr-smUvQhALK61xxZUQ1lyoRk',
#  'nextPageToken': 'CBQQAA',
#  'regionCode': 'VN',
#  'pageInfo': {'totalResults': 150, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'ETh1H_dsc1o1dPTG5IF1dzBWPTA',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCdnBdcPkmvEU_JK3_SFDxtw'},
#    'snippet': {'publishedAt': '2023-01-16T13:50:33Z',
#     'channelId': 'UCdnBdcPkmvEU_JK3_SFDxtw',
#     'title': 'Team Huyền Thoại Châu Phi',
#     'description': 'Mua Áo Của Team Châu Phi : https://shopee.vn/quanglinhstore ▻ Mua Nước Hoa Tại: https://www.facebook.com/quanglinhstore ...',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com
00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jtszIfJtcaZQzxBPqYQ3-5nk4dA',
#    'id': {'kind': 'youtube#video', 'videoId': 'V7N3qxiFSu8'},
#    'snippet': {'publishedAt': '2024-05-01T11:00:23Z',
#     'channelId': 'UCdnBdcPkmvEU_JK3_SFDxtw',
#     'title': 'Team Huyền Thoại || Cười Sảng Với Trận Chiến Đi Cầu Khỉ - Trò Chơi Dân Gian Việt Nam',
#     'description': 'Mua Áo Của Team Châu Phi : https://shopee.vn/quanglinhstore ▻ Mua Nước Hoa Tại: https://www.facebook.com/quanglinhstore ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/V7N3qxiFSu8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/V7N3qxiFSu8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/V7N3qxiFSu8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Team Huyền Thoại Châu Phi',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-01T11:00:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'EblLiVrQtAO2DD4rY1fl1Zh9vEA',
#    'id': {'kind': 'youtube#video', 'videoId': 'w2iawqLnk24'},
#    'snippet': {'publishedAt': '2024-05-04T11:00:48Z',
#     'channelId': 'UCdnBdcPkmvEU_JK3_SFDxtw',
#     'title': 'Team Huyền Thoại || Nhảy Lò Cò Truyền Nước Trên Xà Phòng, Ai Là Người Có Cú Ngã Đẹp Nhất 🤣🤣🤣',
#     'description': 'Mua Áo Của Team Châu Phi : https://shopee.vn/quanglinhstore ▻ Mua Nước Hoa Tại: https://www.facebook.com/quanglinhstore ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w2iawqLnk24/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/w2iawqLnk24/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/w2iawqLnk24/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Team Huyền Thoại Châu Phi',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-04T11:00:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'M-ajJtW0xDnK7qtEye5M2kRyTss',
#    'id': {'kind': 'youtube#video', 'videoId': 'l6XBhme6z5c'},
#    'snippet': {'publishedAt': '2024-05-25T11:00:44Z',
#     'channelId': 'UCdnBdcPkmvEU_JK3_SFDxtw',
#     'title': 'Team Huyền Thoại || Ai Sẽ Trở Thành Vua Né Tránh??? Các Cây Hài Sắp Thành Thạo Tiếng Việt.',
#     'description': 'Mua Áo Của Team Châu Phi : https://shopee.vn/quanglinhstore ▻ Mua Nước Hoa Tại: https://www.facebook.com/quanglinhstore ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/l6XBhme6z5c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/l6XBhme6z5c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/l6XBhme6z5c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Team Huyền Thoại Châu Phi',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-25T11:00:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vILxvwWL_FnY0mff8N3oZzhDhS0',
#    'id': {'kind': 'youtube#video', 'videoId': '_HIpiVLlWUI'},
#    'snippet': {'publishedAt': '2024-05-08T11:00:34Z',
#     'channelId': 'UCdnBdcPkmvEU_JK3_SFDxtw',
#     'title': 'Team Huyền Thoại || 1001 Tư Thế Độc Lạ Khi Tham Gia Thử Thách Mặc Quần Không Dùng Tay 🤣🤣',
#     'description': 'Mua Áo Của Team Châu Phi : https://shopee.vn/quanglinhstore ▻ Mua Nước Hoa Tại: https://www.facebook.com/quanglinhstore ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_HIpiVLlWUI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_HIpiVLlWUI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_HIpiVLlWUI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Team Huyền Thoại Châu Phi',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-08T11:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xswGbzz81p-cOqXyU2JoE5BcJxQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'OgLQOlzEr1o'},
#    'snippet': {'publishedAt': '2024-05-11T11:00:16Z',
#     'channelId': 'UCdnBdcPkmvEU_JK3_SFDxtw',
#     'title': 'Team Huyền Thoại || Thử Thách Ăn Xúc Xích Bằng Chân -Miếng Ăn Tới Miệng Còn Tuột Mất 🤣🤣',
#     'description': 'Mua Áo Của Team Châu Phi : https://shopee.vn/quanglinhstore ▻ Mua Nước Hoa Tại: https://www.facebook.com/quanglinhstore ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OgLQOlzEr1o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OgLQOlzEr1o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OgLQOlzEr1o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Team Huyền Thoại Châu Phi',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-11T11:00:16Z'}}]}

# %%
for i,video_Id in enumerate(video_Ids):
    url = f"https://www.googleapis.com/youtube/v3/videos?part=statistics,snippet&key={api_key}&id={video_Id}"
    data = json.loads(requests.get(url).text)
    channel_id = data['items'][0]['snippet']['channelId']      
    published_date = data['items'][0]['snippet']['publishedAt']    
    video_title =  data['items'][0]['snippet']['title']     
    video_description = data['items'][0]['snippet']['description']
    likes =  data["items"][0]["statistics"]["likeCount"]
   # dislikes = data["items"][0]["statistics"]["dislikeCount"]
    views = data["items"][0]["statistics"]["viewCount"]
    comment_count = data["items"][0]["statistics"]['commentCount']
    row = [video_Id,channel_id,published_date,
           video_title,video_description,
           likes,views,comment_count]
    data_df.loc[i]=row

# %%
data_df.to_csv('quanglinhvlog.csv',index=False)

# %%
# Importing operating system library to views files and interacting with system
import os
os.listdir() # Shows all the files available in current directory
# Out:
# ['.ipynb_checkpoints',
#  'quanglinhvlog.csv',
#  'Scraping data from youtube.ipynb',
#  'Untitled1.ipynb']

# %%
import pandas as pd
quanglingvlog_df = pd.read_csv('quanglinhvlog.csv')

# %%
quanglingvlog_df.head()
# Out:
#       video_id                channel_id        published_date  \
# 0  JMwfg3RzXZQ  UCdnBdcPkmvEU_JK3_SFDxtw  2024-04-27T11:00:27Z
# 1  jqzO-srikcs  UCdnBdcPkmvEU_JK3_SFDxtw  2024-06-24T11:00:45Z
# 2  Anq36w5xCRo  UCdnBdcPkmvEU_JK3_SFDxtw  2024-04-30T11:00:07Z
# 3  CNrT7dCWoZk  UCdnBdcPkmvEU_JK3_SFDxtw  2024-05-19T11:00:09Z
# 4  kBVonIkqqBQ  UCdnBdcPkmvEU_JK3_SFDxtw  2024-04-26T11:00:42Z
#
#                                          video_title  \
# 0  Team Huyền Thoại || Thử Thách Đu Cây Chuối Bôi...
# 1  Đi "Thăng Bằng" Trên Thùng Phi??? Ai Là Người ...
# 2  Team Huyền Thoại || Thử Thách Đạp Xe Qua Cầu K...
# 3  Team Huyền Thoại || Thi Bằng Lái Xe Đạp Qua Vò...
# 4  Team Huyền Thoại || Trò Chơi Tuổi Thơ " Phi Ti...
#
#                                    video_description  likes   views  \
# 0  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  26333  697305
# 1  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  10536  149892
# 2  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  28081  617774
# 3  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  12322  168047
# 4  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  12836  180960
#
#    comment_count
# 0           1274
# 1            496
# 2           1614
# 3            437
# 4            591

# %%
quanglingvlog_df.head()
# Out:
#       video_id                channel_id        published_date  \
# 0  JMwfg3RzXZQ  UCdnBdcPkmvEU_JK3_SFDxtw  2024-04-27T11:00:27Z
# 1  jqzO-srikcs  UCdnBdcPkmvEU_JK3_SFDxtw  2024-06-24T11:00:45Z
# 2  Anq36w5xCRo  UCdnBdcPkmvEU_JK3_SFDxtw  2024-04-30T11:00:07Z
# 3  CNrT7dCWoZk  UCdnBdcPkmvEU_JK3_SFDxtw  2024-05-19T11:00:09Z
# 4  kBVonIkqqBQ  UCdnBdcPkmvEU_JK3_SFDxtw  2024-04-26T11:00:42Z
#
#                                          video_title  \
# 0  Team Huyền Thoại || Thử Thách Đu Cây Chuối Bôi...
# 1  Đi "Thăng Bằng" Trên Thùng Phi??? Ai Là Người ...
# 2  Team Huyền Thoại || Thử Thách Đạp Xe Qua Cầu K...
# 3  Team Huyền Thoại || Thi Bằng Lái Xe Đạp Qua Vò...
# 4  Team Huyền Thoại || Trò Chơi Tuổi Thơ " Phi Ti...
#
#                                    video_description  likes   views  \
# 0  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  26333  697305
# 1  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  10536  149892
# 2  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  28081  617774
# 3  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  12322  168047
# 4  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  12836  180960
#
#    comment_count
# 0           1274
# 1            496
# 2           1614
# 3            437
# 4            591

# %%
print(quanglingvlog_df['published_date'].dtype)
# Out:
# object

# %%
quanglingvlog_df['published_date'] = pd.to_datetime(quanglingvlog_df['published_date'])

# %%
time = []
date = []
year = []
month = []
day = []
i = 0
for i in range(quanglingvlog_df.shape[0]):
    t = quanglingvlog_df['published_date'][i].time()
    d = quanglingvlog_df['published_date'][i].date()
    y = quanglingvlog_df['published_date'][i].date().year
    m = quanglingvlog_df['published_date'][i].date().month
    da = quanglingvlog_df['published_date'][i].date().day
    time.append(t)
    date.append(d)
    year.append(y)
    month.append(m)
    day.append(da)
    i = i + 1

# %%
quanglingvlog_df.drop('published_date', inplace = True, axis = 1)
quanglingvlog_df['published_date'] = date
quanglingvlog_df['published_time'] = time
quanglingvlog_df['published_year'] = year
quanglingvlog_df['published_month'] = month
quanglingvlog_df['published_day'] = day

# %%
quanglingvlog_df.head()
# Out:
#       video_id                channel_id  \
# 0  JMwfg3RzXZQ  UCdnBdcPkmvEU_JK3_SFDxtw
# 1  jqzO-srikcs  UCdnBdcPkmvEU_JK3_SFDxtw
# 2  Anq36w5xCRo  UCdnBdcPkmvEU_JK3_SFDxtw
# 3  CNrT7dCWoZk  UCdnBdcPkmvEU_JK3_SFDxtw
# 4  kBVonIkqqBQ  UCdnBdcPkmvEU_JK3_SFDxtw
#
#                                          video_title  \
# 0  Team Huyền Thoại || Thử Thách Đu Cây Chuối Bôi...
# 1  Đi "Thăng Bằng" Trên Thùng Phi??? Ai Là Người ...
# 2  Team Huyền Thoại || Thử Thách Đạp Xe Qua Cầu K...
# 3  Team Huyền Thoại || Thi Bằng Lái Xe Đạp Qua Vò...
# 4  Team Huyền Thoại || Trò Chơi Tuổi Thơ " Phi Ti...
#
#                                    video_description  likes   views  \
# 0  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  26333  697305
# 1  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  10536  149892
# 2  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  28081  617774
# 3  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  12322  168047
# 4  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  12836  180960
#
#    comment_count published_date published_time  published_year  \
# 0           1274     2024-04-27       11:00:27            2024
# 1            496     2024-06-24       11:00:45            2024
# 2           1614     2024-04-30       11:00:07            2024
# 3            437     2024-05-19       11:00:09            2024
# 4            591     2024-04-26       11:00:42            2024
#
#    published_month  published_day
# 0                4             27
# 1                6             24
# 2                4             30
# 3                5             19
# 4                4             26

# %%
quanglingvlog_df.drop(['channel_id', 'video_id'], inplace = True, axis = 1)

# %%
quanglingvlog_df.head()
# Out:
#                                          video_title  \
# 0  Team Huyền Thoại || Thử Thách Đu Cây Chuối Bôi...
# 1  Đi "Thăng Bằng" Trên Thùng Phi??? Ai Là Người ...
# 2  Team Huyền Thoại || Thử Thách Đạp Xe Qua Cầu K...
# 3  Team Huyền Thoại || Thi Bằng Lái Xe Đạp Qua Vò...
# 4  Team Huyền Thoại || Trò Chơi Tuổi Thơ " Phi Ti...
#
#                                    video_description  likes   views  \
# 0  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  26333  697305
# 1  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  10536  149892
# 2  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  28081  617774
# 3  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  12322  168047
# 4  ► Mua Áo Của Team Châu Phi : https://shopee.vn...  12836  180960
#
#    comment_count published_date published_time  published_year  \
# 0           1274     2024-04-27       11:00:27            2024
# 1            496     2024-06-24       11:00:45            2024
# 2           1614     2024-04-30       11:00:07            2024
# 3            437     2024-05-19       11:00:09            2024
# 4            591     2024-04-26       11:00:42            2024
#
#    published_month  published_day
# 0                4             27
# 1                6             24
# 2                4             30
# 3                5             19
# 4                4             26

# %%
import datetime

for i in range(quanglingvlog_df.shape[0]):
    value = quanglingvlog_df['published_date'].at[i]
    if isinstance(value, str):  # Chỉ chuyển đổi nếu giá trị là chuỗi
        date_time_adjust = datetime.datetime.strptime(value, '%Y-%m-%dT%H:%M:%SZ')
        quanglingvlog_df['published_date'].at[i] = date_time_adjust

# %%
print('Number of rows = ',quanglingvlog_df.shape[0], '\nNumber of columns = ', quanglingvlog_df.shape[1], '\nSize of the dataset = ',quanglingvlog_df.size, 'element')
# Out:
# Number of rows =  19
# Number of columns =  10
# Size of the dataset =  190 element

# %%
quanglingvlog_df.describe()
# Out:
#               likes          views  comment_count  published_year  \
# count     19.000000      19.000000      19.000000            19.0
# mean   18996.157895  331189.526316    1187.157895          2024.0
# std     7603.353736  214897.255164     663.135252             0.0
# min    10170.000000  122199.000000     437.000000          2024.0
# 25%    13154.000000  181532.500000     617.500000          2024.0
# 50%    16000.000000  250340.000000    1079.000000          2024.0
# 75%    24508.000000  490492.000000    1491.500000          2024.0
# max    34701.000000  819042.000000    2948.000000          2024.0
#
#        published_month  published_day
# count        19.000000      19.000000
# mean          4.631579      16.000000
# std           0.597265       9.775252
# min           4.000000       1.000000
# 25%           4.000000       8.500000
# 50%           5.000000      16.000000
# 75%           5.000000      25.500000
# max           6.000000      30.000000

# %%
quanglingvlog_df[['likes', 'views', 'comment_count']].sum()
# Out:
# likes             360927
# views            6292601
# comment_count      22556
# dtype: int64

# %%
AvgLikes = quanglingvlog_df.describe()['likes']['mean']
AvgViews = quanglingvlog_df.describe()['views']['mean']
AvgComments = quanglingvlog_df.describe()['comment_count']['mean']
print('Average number of views on video = ', AvgViews,'\nAverage number of comments = ', AvgComments, '\nAverage number of likes = ', AvgLikes)
# Out:
# Average number of views on video =  331189.5263157895
# Average number of comments =  1187.157894736842
# Average number of likes =  18996.157894736843

# %%
import seaborn as sns
import matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (12, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

# Trục đầu tiên: Biểu đồ tròn cho người xem phản ứng với video
ax1 = fig.add_axes([0, 0, 0.75, 0.75], aspect=1)
pie_vars = ['Reacters', 'Neutral']
pie_values = [quanglingvlog_df['likes'].sum(), quanglingvlog_df['views'].sum() - quanglingvlog_df['likes'].sum()]
ax1.pie(pie_values, labels=pie_vars, autopct='%1.2f%%')
ax1.set_title('Viewers who react on video')

# Trục thứ hai: Biểu đồ tròn cho loại người phản ứng
ax2 = fig.add_axes([0.8, 0, 0.75, 0.75], aspect=1)
pie_vars = ['Likers', 'Commenters']  # Chỉ sử dụng hai nhãn để khớp với hai giá trị
pie_values = [quanglingvlog_df['likes'].sum(), quanglingvlog_df['comment_count'].sum()]
ax2.pie(pie_values, labels=pie_vars, autopct='%1.2f%%')
ax2.set_title('Type of reacters')

# Trục thứ ba: Biểu đồ tròn cho người bình luận so với không bình luận
ax3 = fig.add_axes([0.4, -0.75, 0.75, 0.75], aspect=1)
pie_vars = ['Comments', 'Non-Commenters']
pie_values = [quanglingvlog_df['comment_count'].sum(), quanglingvlog_df['views'].sum() - quanglingvlog_df['comment_count'].sum()]
ax3.pie(pie_values, labels=pie_vars, autopct='%1.2f%%')
ax3.set_title('Viewers vs total comments')

plt.show()

# %%
import matplotlib.pyplot as plt

# Tạo một figure với ba trục (subplots) theo hàng ngang (1, 3) - một hàng, ba cột
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)

# Biểu đồ 1: Hiển thị số lượt xem, số người đăng ký, lượt thích và bình luận trung bình
bar_vars = ['Views', 'Subscribers', 'Likes', 'Comments']  # Các nhãn cột
bar_values = [
    quanglingvlog_df.describe()['views']['mean'],  # Giá trị trung bình của lượt xem
    channel_subscribers,  # Số người đăng ký (giá trị này cần được xác định từ trước)
    quanglingvlog_df.describe()['likes']['mean'],  # Giá trị trung bình của lượt thích
    quanglingvlog_df.describe()['comment_count']['mean']  # Giá trị trung bình của bình luận
]
ax1.bar(bar_vars, bar_values)  # Tạo biểu đồ cột
ax1.set_xticks(bar_vars)  # Đặt các nhãn trục x
ax1.set_xticklabels(bar_vars, rotation=90)  # Xoay nhãn trục x 90 độ để dễ đọc
ax1.set_title('Figure 1')  # Đặt tiêu đề cho biểu đồ 1

# Biểu đồ 2: Hiển thị số lượt xem, lượt thích và bình luận trung bình
bar_vars = ['Views', 'Likes', 'Comments']  # Các nhãn cột
bar_values = [
    quanglingvlog_df.describe()['views']['mean'],  # Giá trị trung bình của lượt xem
    quanglingvlog_df.describe()['likes']['mean'],  # Giá trị trung bình của lượt thích
    quanglingvlog_df.describe()['comment_count']['mean']  # Giá trị trung bình của bình luận
]
ax2.bar(bar_vars, bar_values)  # Tạo biểu đồ cột
ax2.set_xticks(bar_vars)  # Đặt các nhãn trục x
ax2.set_xticklabels(bar_vars, rotation=90)  # Xoay nhãn trục x 90 độ để dễ đọc
ax2.set_title('Figure 2')  # Đặt tiêu đề cho biểu đồ 2

# Biểu đồ 3: Hiển thị lượt thích và bình luận trung bình
bar_vars = ['Likes', 'Comments']  # Các nhãn cột
bar_values = [
    quanglingvlog_df.describe()['likes']['mean'],  # Giá trị trung bình của lượt thích
    quanglingvlog_df.describe()['comment_count']['mean']  # Giá trị trung bình của bình luận
]
ax3.bar(bar_vars, bar_values)  # Tạo biểu đồ cột
ax3.set_xticks(bar_vars)  # Đặt các nhãn trục x
ax3.set_xticklabels(bar_vars, rotation=90)  # Xoay nhãn trục x 90 độ để dễ đọc
ax3.set_title('Figure 3')  # Đặt tiêu đề cho biểu đồ 3

# Điều chỉnh bố cục để các biểu đồ không bị chồng chéo và có khoảng cách đều nhau
plt.tight_layout(pad=2)

# Hiển thị toàn bộ các biểu đồ
plt.show()
